# %%
import layeris
from layeris import LayerImage

print(f"layeris.__version__: {layeris.__version__}")
# Out:
# layeris.__version__: 0.3.2

# %%
image = LayerImage.from_file("test-images/carpenter-01.jpg")
image
